# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib

# Charger les données utilisées pour entraîner le modèle
data = pd.read_csv("data/nouveau_donnee_maladie.csv")

# %%
# Initialiser un dictionnaire pour stocker les LabelEncoder
label_encoders = {}

# Créer et entraîner les LabelEncoder pour chaque colonne catégorielle
for column in data.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    le.fit(data[column])
    label_encoders[column] = le
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 label_encoders = {}
#       4 # Créer et entraîner les LabelEncoder pour chaque colonne catégorielle
# ----> 5 for column in data.select_dtypes(include=['object']).columns:
#       6     le = LabelEncoder()
#       7     le.fit(data[column])
#
# NameError: name 'data' is not defined

# %%
# Sauvegarder les LabelEncoder dans un fichier
joblib.dump(label_encoders, 'models/label_nouveau_encoders.joblib')
# Out:
# ['models/label_nouveau_encoders.joblib']
